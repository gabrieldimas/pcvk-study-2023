# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrieldimas/PCVK_Ganjil_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MODUL 1 – Penggunaan Github dan Google Colaboratory, Membaca dan Menampilkan Citra

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://placekitten.com/800/571"]
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#print resolusi gambar

tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = " ,tinggi," x " ,lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
#garis horizontal di tengah

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# # Pertanyaan
#
# Soal :
#
# 1.	Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# 2.	Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# 3.	Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#  ![image.png](data:image/png;base64,...)
#
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# 4.	Perhatikan potongan kode progam berikut :
#
#  ![image.png](data:image/png;base64,...)
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# 5.	Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# Jawaban :
#
# 1.	Ada beberapa kelebihan jika kita menggunakan google collab daripada local dalam mengeksekusi kode Python antara lain :
# a.	Tidak memerlukan pengaturan dan menginstal tambahan-tambahan lainnya, cukup memanggil dari library
# b.	Akses cloud
# c.	TPU dan GPU gratis
# d.	Kolaborasi mudah
# e.	Selain bisa menyimpan di GitHub, kita juga bisa menyimpan salinan di Google Drive
# 2.	Di langkah ke 8, ada beberapa library yang dipakai, antara lain :
# a.	Numpy, untuk operasi matematika dan statistik pada array multidimensi dengan cepat
# b.	Pandas, untuk analisis data dan manipulasi data dalam bentuk tabel atau DataFrame
# c.	CV2, untuk memproses dan menganalisis gambar dan vieo
# d.	Skimage, untuk pemrosesan gambar dan visi komputer yang menyediakan berbagai algoritma seperti filtering, transofmrasi, segmentasi, dan analisis fitur
# e.	Matplotlib, untuk visualisasi data dalam bentuk grafik dan plot
# Apakah semua library tersebut harus digunakan? Tidak, sesuai kebutuhan saja.
# 3.	Makna potongan kode berikut adalah :
# a.	Image, merujuk pada variabel yang menyatakan gambar
# b.	cv.resize(image, (0,0), fx=0.5, fy=0.5), adalah pemanggilan fungsi resize atau scaling pada library OpenCV
# c.	(0,0) adalah ukuran target, jika kita mengisi 0 maka gambar akan otomatis mengikuti faktor skalanya
# d.	Parameter fx dan fy adalah faktor skala sumbu x dan y. Jika kita mengisi 0,5 maka gambar akan diubah menjadi setengah dari ukuran aslinya
# 4.	Makna dari kode [255,255,255] adalah memberikan warna pada gambar. Ada 3 angka yang menyatakan tiap R, G, dan B dan menghasilkan kombinasi warna dimana 255,255,255 adalah warna putih
# 5.	Semakin tinggi pixel resolusi gambar akan semakin tinggi, begitu pula sebaliknya.

# %% [markdown]
# ## Tugas

# %%
#garis vertikal

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(tinggi):
  image_3[y, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#garis diagonal

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3, (0,0), (lebar, tinggi), (255,255,255))
cv.line(image_3, (400,0), (0, tinggi), (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#garis sembarang

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3, (100,100), (300, 100), (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#kotak

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.rectangle(image_3, (180,140), (300, 200), (255,255,255), (-1))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ## Tugas Kelompok (KTP)
#
# Bentuk kelompok masing-masing terdiri dari 2-3 orang. tiap kelompok lakukan langkah berikut:
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa
# konversi pada opencv (**Jawaban :** karena OpenCV menggunakan format BGR dan matplotlib menggunakan format RGB sehingga ketika kita ingin menampilkan gambar dengan OpenCV, kita tidak perlu mengubah format menjadi RGB)
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor
# NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian
# Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup
# bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan.
# Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten
# dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian
# nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW
# dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh
# menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Kuliah/PCVK/assets/KTP.jpeg'
image_ktp = cv.imread(path)
image_ktp = cv.cvtColor(image_ktp,cv.COLOR_BGR2RGB)
plt.imshow(image_ktp)

# %% [markdown]
# #Kelompok 8
#
# Tugas : tutup bagian kabupaten
# dan tanggal dikeluarkan KTP yang ada dibagian bawah foto.

# %%
color_yellow = (248,253,95)
color_black = (0,0,0)

image_ktp[340:360,630:730] = color_yellow
image_ktp[365:390,630:730] = color_black

plt.imshow(image_ktp)
